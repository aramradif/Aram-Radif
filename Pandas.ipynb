# %% [markdown]
# <a href="https://colab.research.google.com/github/aramradif/Aram-Radif/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
mylist = [50, 100, 150, 200, 250, 300]
res = pd.Series(mylist)
print(res)
# Out:
# 0     50
# 1    100
# 2    150
# 3    200
# 4    250
# 5    300
# dtype: int64
